# %%
# Write a Python program to check whether a number entered by the user is positive.
number = float(input("Enter a number: "))
if number > 0:
    print("The number is positive.")
else:
    print("The number is not positive.")
# Out:
# Enter a number:  4
# The number is positive.

# %%
# Write a program to check whether a given number is divisible by 5.
num = int(input("Enter a number: "))
if num % 5 == 0:
    print(f"{num} is divisible by 5.")
else:
    print(f"{num} is not divisible by 5.")
# Out:
# Enter a number:  2
# 2 is not divisible by 5.

# %%
# Write a program to check whether the entered age is greater than 60 (senior citizen).
age = int(input("Enter your age: "))
if age > 60:
    print("You are a senior citizen.")
else:
    print("You are not a senior citizen.")
# Out:
# Enter your age:  4
# You are not a senior citizen.

# %%
# Write a Python program to check whether a number is even or odd using if-else.
number = int(input("Enter a number: "))
if number % 2 == 0:
    print(f"{number} is even.")
else:
    print(f"{number} is odd.")
# Out:
# Enter a number:  2
# 2 is even.

# %%
# Write a program to check whether a student passed or failed (pass mark = 40).
marks = float(input("Enter your marks: "))
if marks >= 40:
    print("You have passed.")
else:
    print("You have failed.")
# Out:
# Enter your marks:  3
# You have failed.

# %%
# Write a program to find the largest of two numbers using if-else.
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
if a > b:
    print(f"{a} is the largest number.")
else:
    print(f"{b} is the largest number.")
# Out:
# Enter first number:  2
# Enter second number:  1
# 2.0 is the largest number.

# %%
# Write a program to check whether a character entered by the user is a vowel or a consonant.
char = input("Enter a character: ").lower()
if char in "aeiou":
    print(f"{char} is a vowel.")
else:
    print(f"{char} is a consonant.")
# Out:
# Enter a character:  f
# f is a consonant.

# %%
# Write a Python program to check whether a number is positive, negative, or zero using nested-if.
num = float(input("Enter a number: "))
if num >= 0:
    if num == 0:
        print("The number is Zero")
    else:
        print("The number is Positive")
else:
    print("The number is Negative")
# Out:
# Enter a number:  3
# The number is Positive

# %%
# Write a program to calculate the grade of a student using nested-if:
# ≥90 → A
# 75–89 → B
# 50–74 → C
# <50 → Fail

marks = int(input("Enter your marks: "))
if marks >= 90:
    grade = "A"
else:
    if marks >= 75:
        grade = "B"
    else:
        if marks >= 50:
            grade = "C"
        else:
            grade = "Fail"

print("Grade:", grade)
# Out:
# Enter your marks:  2
# Grade: Fail

# %%
# Write a program to find the largest of three numbers using nested-if.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
if a >= b:
    if a >= c:
        print(f"{a} is the largest number.")
    else:
        print(f"{c} is the largest number.")
else:
    if b >= c:
        print(f"{b} is the largest number.")
    else:
        print(f"{c} is the largest number.")
# Out:
# Enter first number:  3
# Enter second number:  2
# Enter third number:  4
# 4 is the largest number.
