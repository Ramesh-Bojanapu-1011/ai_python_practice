# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "Year": [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
        "Sales": [2000, 2300, 4800, 3500, 6000, 5200, 4900, 6300],
    }
)
df
# Out:
#    Year  Sales
# 0  2017   2000
# 1  2018   2300
# 2  2019   4800
# 3  2020   3500
# 4  2021   6000
# 5  2022   5200
# 6  2023   4900
# 7  2024   6300

# %% [markdown]
# If we create graph by the using of datafarame we dont need plt.legend()

# %%
df.plot("Year", "Sales", kind="line", label="sales per year", color="red")
plt.title("Simple Line Plot")
plt.xlabel("Year section")
plt.ylabel("Sales as per year")
plt.show()

# %%
df.plot("Year", "Sales", kind="bar", label="sales per year", color="red")
plt.title("Simple Line Plot")
plt.xlabel("Year section")
plt.ylabel("Sales as per year")
plt.show()

# %%
df.plot("Year", "Sales", kind="scatter", label="sales per year", color="red")
plt.title("Simple Line Plot")
plt.xlabel("Year section")
plt.ylabel("Sales as per year")
plt.show()

# %% [markdown]
# If we create graph by the without using of datafarame we need plt.legend()

# %%
plt.plot(df.Year, df.Sales, label="sales per year", color="red")
plt.title("Simple Line Plot")
plt.xlabel("Year section")
plt.ylabel("Sales as per year")
plt.legend()
plt.show()

# %%
plt.bar(df.Year, df.Sales, label="sales per year", color="red")
plt.title("Simple Line Plot")
plt.xlabel("Year section")
plt.ylabel("Sales as per year")
plt.legend()
plt.show()

# %% [markdown]
# Marker Line Chart

# %% [markdown]
# Color codes for stying of graph
# | Letter | Color Name |
# | ------ | ---------- |
# | `b` | Blue |
# | `g` | Green |
# | `r` | Red |
# | `c` | Cyan |
# | `m` | Magenta |
# | `y` | Yellow |
# | `k` | Black |
# | `w` | White |

# %%
df.plot(
    "Year",
    "Sales",
    kind="line",
    title="Simple Line Plot",
    label="sales per year",
    style="b-.^",  # 'color:line_style:marker'
)

plt.xlabel("Year")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# multi line plot for two lines

# %%
product = pd.DataFrame(
    {
        "Year": [2017, 2018, 2019, 2020, 2021, 2022],
        "ProdASales": [2000, 3000, 4000, 3500, 6000, 5300],
        "ProdBSales": [3000, 4000, 3500, 3500, 5500, 6100],
    }
)
product
# Out:
#    Year  ProdASales  ProdBSales
# 0  2017        2000        3000
# 1  2018        3000        4000
# 2  2019        4000        3500
# 3  2020        3500        3500
# 4  2021        6000        5500
# 5  2022        5300        6100

# %%
ax1 = product.plot(
    "Year", "ProdASales", kind="line", label="Product A Sales", style="r-*"
)
product.plot(
    "Year",
    "ProdBSales",
    ax=ax1,
    kind="line",
    label="Product B Sales",
    title="MultiLine Plot",
    style="b--o",
)  # ax : axes object
plt.xlabel("Year")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# multi line plot for Three lines

# %%
product2 = pd.DataFrame(
    {
        "Year": [2017, 2018, 2019, 2020, 2021, 2022],
        "ProdASales": [2000, 3000, 4000, 3500, 6000, 5300],
        "ProdBSales": [3000, 4000, 3500, 3500, 5500, 6100],
        "ProdCSales": [3900, 2000, 3100, 5000, 4500, 4200],
    }
)
product2
# Out:
#    Year  ProdASales  ProdBSales  ProdCSales
# 0  2017        2000        3000        3900
# 1  2018        3000        4000        2000
# 2  2019        4000        3500        3100
# 3  2020        3500        3500        5000
# 4  2021        6000        5500        4500
# 5  2022        5300        6100        4200

# %%
product2.plot(
    "Year",
    ["ProdASales", "ProdBSales", "ProdCSales"],
    kind="line",
    title="MultiLine Plot for 3 Products",
    style=["r-*", "b--o", "g-.^"],
)
plt.xlabel("Year")
plt.ylabel("Sales")
plt.show()
